# %% [markdown]
# ## Лекция 2  BM5

# %% [markdown]
# ## Функция ранжирования bm25

# %% [markdown]
# Для обратного индекса есть общепринятая формула для ранжирования *Okapi best match 25* ([Okapi BM25](https://ru.wikipedia.org/wiki/Okapi_BM25)).
# Пусть дан запрос $Q$, содержащий слова  $q_1, ... , q_n$, тогда функция BM25 даёт следующую оценку релевантности документа $D$ запросу $Q$:
#
# $$ score(D, Q) = \sum_{i}^{n} \text{IDF}(q_i)*\frac{TF(q_i,D)*(k+1)}{TF(q_i,D)+k(1-b+b\frac{l(d)}{avgdl})} $$
# где
# >$TF(q_i,D)$ - частота слова $q_i$ в документе $D$
# $l(d)$ - длина документа (количество слов в нём)
# *avgdl* — средняя длина документа в коллекции
# $k$ и $b$ — свободные коэффициенты, обычно их выбирают как $k$=2.0 и $b$=0.75
# $$$$
# $\text{IDF}(q_i)$ - это модернизированная версия IDF:
# $$\text{IDF}(q_i) = \log\frac{N-n(q_i)+0.5}{n(q_i)+0.5},$$
# >> где $N$ - общее количество документов в коллекции
# $n(q_i)$ — количество документов, содержащих $q_i$

# %%
all = []
numb = 0
import csv
with open('quora_question_pairs_rus.csv') as qd:
    qd = csv.reader(qd, delimiter=',')
    for raw in qd:
        numb += 1
        if numb < 500 and numb >= 2:
            all.append(raw)

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
import nltk
import collections
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
nltk.download("stopwords")
from nltk.corpus import stopwords
russian_stopwords = stopwords.words("russian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mayakorotkaya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re

# %%
normal = []
for i in all:
    normal_pair = []
    normal_query = []
    normal_doc = []
    for t in tokenizer.tokenize(i[1]):
        t = morph.parse(t)[0]
        if t.normal_form not in russian_stopwords and t.normal_form != 'это' and t.normal_form != 'весь' and not re.match(r'[0-9A-Za-z]', t.normal_form):
            normal_query.append(t.normal_form)
    normal_pair.append(normal_query)
    for k in tokenizer.tokenize(i[2]):
        k = morph.parse(k)[0]
        if k.normal_form not in russian_stopwords and k.normal_form != 'это' and k.normal_form != 'весь' and not re.match(r'[0-9A-Za-z]', k.normal_form):
            normal_doc.append(k.normal_form)
    normal_pair.append(normal_doc)
    normal_pair.append(i[3])
    normal.append(normal_pair)

# %%
all

# %%
normal
# Out:
# [[['каков', 'история', 'кохинор', 'кох', 'ноор', 'бриллиант'],
#   ['произойти',
#    'правительство',
#    'индия',
#    'украсть',
#    'кохинор',
#    'кох',
#    'ноор',
#    'алмаз',
#    'назад'],
#   '0'],
#  [['мочь', 'увеличить', 'скорость', 'интернет', 'соединение', 'использовать'],
#   ['повысить', 'скорость', 'интернет', 'путём', 'взлом'],
#   '0'],
#  [['почему', 'мысленно', 'очень', 'одинокий', 'мочь', 'решить'],
#   ['найти', 'остаток', 'математика', 'математика', 'разделить'],
#   '0'],
#  [['который',
#    'растворять',
#    'вода',
#    'быстро',
#    'сахарный',
#    'соль',
#    'метан',
#    'углеродный',
#    'диоксид'],
#   ['рыба', 'выжить', 'солёный', 'вода'],
#   '0'],
#  [['астрология',
#    'луна',
#    'колпачок',
#    'козерог',
#    'крышка',
#    'поднимать',
#    'говорить'],
#   ['тройной', 'луна', 'козерог', 'восхождение', 'козерог', 'говорить'],
#   '1'],
#  [['должный', 'купить'],
#   ['делать', 'ребёнок', 'активный', 'далёкий', 'телефонный', 'видеоигра'],
#   '0'],
#  [['мочь', 'хороший', 'геолог'],
#   ['должный', 'делать', 'великое', 'геолог'],
#   '1'],
#  [['использовать', 'вместо'], ['использовать', 'вместо'], '0'],
#  [['компания', 'мочь', 'взломать', 'чартер'],
#   ['мочь', 'взломать', 'бесплатный', 'интернет'],
#   '0'],
#  [['метод',
#    'определение',
#    'разделение',
#    'прорезь',
#    'использование',
#    'бипризма',
#    'френель'],
#   ['некоторый',
#    'технический',
#    'специалист',
#    'мочь',
#    'рассказать',
#    'долговечность',
#    'надёжность',
#    'ноутбук',
#    'компонент'],
#   '0'],
#  [['читать', 'находить', 'комментарий'],
#   ['мочь', 'увидеть', 'комментарий'],
#   '1'],
#  [['мочь', 'сделать', 'физика', 'лёгкий', 'изучение'],
#   ['мочь', 'легко', 'научиться', 'физика'],
#   '1'],
#  [['ваш', 'сексуальный', 'опыт'], ['ваш', 'сексуальный', 'опыт'], '1'],
#  [['каков',
#    'закон',
#    'изменение',
#    'ваш',
#    'статус',
#    'студенческий',
#    'виза',
#    'зелёный',
#    'карта',
#    'сравниваться',
#    'иммиграционный',
#    'законодательство',
#    'канада'],
#   ['каков',
#    'закон',
#    'изменение',
#    'ваш',
#    'статус',
#    'студенческий',
#    'виза',
#    'зелёный',
#    'карта',
#    'сравниваться',
#    'иммиграционный',
#    'закон',
#    'япония'],
#   '0'],
#  [['означать',
#    'президентство',
#    'козырь',
#    'нынешний',
#    'иностранный',
#    'студент',
#    'магистр',
#    'визе'],
#   ['президентство',
#    'козырь',
#    'повлиять',
#    'ученик',
#    'настоящее',
#    'время',
#    'планировать',
#    'учиться'],
#   '1'],
#  [['означать', 'манипуляция'], ['означать', 'манипуляция'], '1'],
#  [['почему', 'девушка', 'хотеть', 'дружить', 'парень', 'который', 'отвергать'],
#   ['ребята', 'чувствовать', 'отказ', 'девушка'],
#   '0'],
#  [['почему',
#    'пользователь',
#    'публиковать',
#    'вопрос',
#    'который',
#    'легко',
#    'ответить'],
#   ['почему', 'человек', 'задавать', 'вопрос', 'который', 'легко', 'ответить'],
#   '1'],
#  [['который', 'являться', 'хороший', 'учреждение', 'цифровой', 'маркетинг'],
#   ['который',
#    'являться',
#    'хороший',
#    'институт',
#    'цифровой',
#    'маркетинг',
#    'пуна'],
#   '0'],
#  [['почему', 'ракета', 'выглядеть', 'белый'],
#   ['почему', 'ракета', 'ускоритель', 'окрасить', 'белый', 'цвета'],
#   '1'],
#  [['заставлять', 'завидуть'], ['мочь', 'сделать', 'ревновать'], '0'],
#  [['вопрос', 'следовать', 'задавать'], ['вопрос', 'должный', 'задать'], '0'],
#  [['сколько', 'кв'], ['мочь', 'найти', 'диаграмма', 'преобразование'], '0'],
#  [['означать', 'каждый', 'смотреть', 'часы', 'цифра', 'одинаковый'],
#   ['сколько', 'день', 'перекрывать', 'рука', 'часы'],
#   '0'],
#  [['каков',
#    'некоторый',
#    'совет',
#    'внедрение',
#    'процесс',
#    'собеседование',
#    'лекарство'],
#   ['каков',
#    'некоторый',
#    'совет',
#    'сделать',
#    'процесс',
#    'собеседование',
#    'дом',
#    'медицинский',
#    'медицина'],
#   '0'],
#  [['веб', 'приложение'], ['каков', 'структура', 'веб', 'приложение'], '0'],
#  [['делать', 'общество', 'слишком', 'большой', 'значение', 'спорт'],
#   ['спорт', 'вносить', 'свой', 'вклад', 'общество'],
#   '0'],
#  [['хороший', 'способ', 'заработать', 'деньга', 'интернет'],
#   ['хороший', 'способ', 'попросить', 'деньга', 'интернет'],
#   '0'],
#  [['должный', 'готовиться', 'заключительный', 'закон'],
#   ['следовать',
#    'знать',
#    'полностью',
#    'готовиться',
#    'заключительный',
#    'экзамен'],
#   '1'],
#  [['хотеть', 'сделать', 'хороший'],
#   ['делать', 'хотя', 'знать', 'хороший'],
#   '0'],
#  [['особый', 'забота', 'нос', 'который', 'задыхаться', 'ночное', 'время'],
#   ['мочь', 'держать', 'нос', 'душный', 'ночное', 'время'],
#   '1'],
#  [['игра', 'престол', 'злодей', 'наиболее', 'вероятный', 'дать', 'милость'],
#   ['игра', 'престол', 'злодей', 'большой', 'понравиться', 'власть'],
#   '1'],
#  [['правительство',
#    'соединить',
#    'штат',
#    'прежний',
#    'занимать',
#    'чёрный',
#    'место',
#    'занятость',
#    'далее',
#    'некоторый',
#    'гражданин',
#    'соединить',
#    'штат',
#    'политический',
#    'взгляд'],
#   ['определяться', 'средний', 'скорость', 'молекула', 'газа'],
#   '0'],
#  [['хороший', 'веб', 'сайт', 'путешествие', 'испания'],
#   ['хороший', 'веб', 'сайт', 'путешествие'],
#   '0'],
#  [['почему',
#    'некоторый',
#    'человек',
#    'думать',
#    'обама',
#    'попытаться',
#    'отнять',
#    'оружие'],
#   ['инициатива',
#    'контроль',
#    'оружие',
#    'забрать',
#    'оружие',
#    'который',
#    'человек'],
#   '0'],
#  [['год',
#    'мочь',
#    'улучшить',
#    'свой',
#    'навык',
#    'должный',
#    'сделать',
#    'стать',
#    'предприниматель',
#    'ближний',
#    'несколько',
#    'год'],
#   ['летний', 'парень', 'мочь', 'стать', 'миллиардер', 'ближний', 'год'],
#   '0'],
#  [['подруга',
#    'спрашивать',
#    'свой',
#    'парень',
#    'почему',
#    'выбрать',
#    'заставлять',
#    'хотеть',
#    'ответить'],
#   ['подруга',
#    'сказать',
#    'должный',
#    'прекратить',
#    'смутить',
#    'свой',
#    'чувство',
#    'пожелать',
#    'отключиться',
#    'позвонить',
#    'спросить',
#    'хотеть',
#    'вернуться'],
#   '0'],
#  [['готовиться'], ['готовиться', 'государственный', 'служба'], '1'],
#  [['каков',
#    'скорость',
#    'сваливание',
#    'крыло',
#    'полностью',
#    'отбросить',
#    'назад'],
#   ['почему',
#    'воздушный',
#    'судно',
#    'прекратить',
#    'использовать',
#    'крыло',
#    'изменяемый',
#    'развёртка',
#    'например'],
#   '0'],
#  [['почему', 'славянин', 'приседать'],
#   ['приседание', 'делать', 'нога', 'толстой'],
#   '0'],
#  [['мочь', 'ожидать', 'знакомый', 'почта', 'подтверждение'],
#   ['мочь', 'ожидать', 'знакомый', 'почта', 'подтверждение'],
#   '0'],
#  [['мочь', 'зарабатывать', 'ежемесячно'],
#   ['мочь', 'делать', 'ежемесячный', 'торг'],
#   '0'],
#  [['являться',
#    'хороший',
#    'ребёнок',
#    'являться',
#    'повстанец',
#    'который',
#    'стоить',
#    'долгосрочный',
#    'перспектива'],
#   ['скучать', 'ребёнок'],
#   '0'],
#  [['университет',
#    'делать',
#    'набирать',
#    'новый',
#    'выпускник',
#    'майор',
#    'искать'],
#   ['университет',
#    'делать',
#    'продукт',
#    'набирать',
#    'новый',
#    'выпускник',
#    'делать',
#    'майор'],
#   '0'],
#  [['каков',
#    'самый',
#    'быстрый',
#    'способ',
#    'увеличить',
#    'число',
#    'последователь'],
#   ['мочь', 'увеличить', 'количество', 'последователь'],
#   '0'],
#  [['дарт',
#    'вейдёр',
#    'сражаться',
#    'дарт',
#    'мол',
#    'легенда',
#    'звёздный',
#    'война'],
#   ['лимит', 'символ', 'описание', 'профиль'],
#   '0'],
#  [['каков',
#    'стадия',
#    'разрыв',
#    'пара',
#    'иметь',
#    'вид',
#    'происходить',
#    'эмоциональный',
#    'разрыв',
#    'мужчина',
#    'женщина'],
#   ['который', 'большой', 'пострадать', 'распад', 'мальчик', 'девочка'],
#   '0'],
#  [['пример', 'продукт', 'который', 'изготовить', 'сырой', 'нефть'],
#   ['продукт', 'сырой', 'нефть'],
#   '1'],
#  [['подружиться'], ['подружиться'], '1'],
#  [['являться',
#    'профессиональный',
#    'пусковой',
#    'установка',
#    'пригодный',
#    'подготовка'],
#   ['онлайн', 'программа', 'начинающий', 'программа'],
#   '1'],
#  [['играть', 'обычный', 'игрок'], ['мочь', 'играть', 'обычный', 'плеер'], '1'],
#  [['грустный'], ['аэродинамически', 'происходить', 'винт', 'вращаться'], '0'],
#  [['самый', 'запоминаться', 'либо', 'почему'],
#   ['самый', 'вкусный', 'блюдо', 'либо', 'почему'],
#   '1'],
#  [['влиять', 'сотрудник', 'полиция', 'налоговый', 'орган'],
#   ['почему', 'мочь', 'сделать', 'домашний', 'задание'],
#   '0'],
#  [['трудно', 'попасть'],
#   ['подавать', 'заявка', 'программа', 'становиться', 'старший'],
#   '0'],
#  [['израиль'],
#   ['парень',
#    'который',
#    'лгать',
#    'свой',
#    'истинный',
#    'чувство',
#    'свой',
#    'друг',
#    'тайно',
#    'привлекать'],
#   '0'],
#  [['хороший', 'рэп', 'песнь', 'танцевать'], ['хороший', 'рэп', 'песня'], '0'],
#  [['неожиданно',
#    'выйти',
#    'мочь',
#    'вспомнить',
#    'свой',
#    'пароль',
#    'понять',
#    'адрес',
#    'электронный',
#    'почта',
#    'восстановление',
#    'большой',
#    'живой',
#    'мочь',
#    'сделать'],
#   ['мочь',
#    'вспомнить',
#    'пароль',
#    'адрес',
#    'электронный',
#    'почта',
#    'восстановление',
#    'мочь',
#    'восстановить',
#    'свой',
#    'адрес',
#    'электронный',
#    'почта'],
#   '1'],
#  [['каков', 'хороший', 'способ', 'изучение', 'французский', 'язык'],
#   ['изучать', 'французский', 'полый'],
#   '0'],
#  [['мочь', 'скачать', 'контент', 'торрент', 'регистрация'],
#   ['надёжный', 'торрент'],
#   '0'],
#  [['нормальный', 'иметь', 'тёмный', 'кольцо', 'вокруг', 'радужка', 'глаз'],
#   ['вызывать', 'тёмный', 'кольцо', 'вокруг', 'радужка', 'следовать', 'лечить'],
#   '0'],
#  [['новый',
#    'книга',
#    'гарри',
#    'поттер',
#    'гарри',
#    'поттер',
#    'проклятый',
#    'ребёнок'],
#   ['насколько', 'плохой', 'новый', 'книга'],
#   '1'],
#  [['почему', 'впадать', 'депрессия'], ['почему', 'впадать', 'депрессия'], '0'],
#  [['мочь', 'найти', 'база', 'дать', 'европейский', 'семейный', 'офис'],
#   ['мочь', 'найти', 'американский', 'база', 'дать', 'семейный', 'офис'],
#   '0'],
#  [['программирование', 'изучать', 'язык', 'программирование'],
#   ['узнавать', 'компьютерный', 'язык', 'например'],
#   '1'],
#  [['хороший', 'книга', 'либо', 'сделать'],
#   ['самый', 'важный', 'книга', 'который', 'либо', 'читать'],
#   '1'],
#  [['мочь', 'либо', 'хранить', 'энергия', 'произвести', 'молния'],
#   ['возможно', 'хранить', 'энергия', 'молния'],
#   '1'],
#  [['каков', 'ваш', 'обзор', 'тестирование', 'производительность'],
#   ['тестирование', 'производительность'],
#   '0'],
#  [['цена',
#    'конфиденциальность',
#    'германия',
#    'приходить',
#    'ещё',
#    'потерять',
#    'получить',
#    'конфиденциальность'],
#   ['человек', 'который', 'искренне', 'пользоваться', 'салат', 'приправа'],
#   '0'],
#  [['каков', 'тип', 'иммунитет'],
#   ['каков', 'различный', 'тип', 'иммунитет', 'наш', 'организм'],
#   '0'],
#  [['расстройство', 'нарциссический', 'личность'],
#   ['нарциссический', 'расстройство', 'личность'],
#   '1'],
#  [['мочь', 'свободно', 'говорить', 'английски'],
#   ['мочь', 'научиться', 'свободно', 'говорить', 'английски'],
#   '1'],
#  [['полезно',
#    'быстрый',
#    'восстановление',
#    'дать',
#    'восстановление',
#    'дать',
#    'помощь',
#    'восстановление',
#    'повредить',
#    'файл',
#    'дать'],
#   ['номер', 'телефон', 'служба', 'поддержка', 'клиент'],
#   '1'],
#  [['который',
#    'являться',
#    'самый',
#    'богатый',
#    'игрок',
#    'время',
#    'мочь',
#    'достигнуть',
#    'уровень'],
#   ['который',
#    'являться',
#    'самый',
#    'богатый',
#    'игрок',
#    'время',
#    'мочь',
#    'достигнуть',
#    'уровень',
#    'качество',
#    'игрок'],
#   '1'],
#  [['стрелять',
#    'пуля',
#    'назад',
#    'самолёт',
#    'идти',
#    'быстрый',
#    'пуля',
#    'пуля',
#    'идти',
#    'назад'],
#   ['делать',
#    'пуля',
#    'быстрый',
#    'скорость',
#    'звук',
#    'выстрел',
#    'пистолет',
#    'невозможно',
#    'делать',
#    'пистолет',
#    'сколько',
#    'разрушение',
#    'происходить'],
#   '0'],
#  [['предотвратить', 'рак', 'молочный', 'железа'],
#   ['предотвращаться', 'рак', 'молочный', 'железа'],
#   '0'],
#  [['выйти', 'учётный', 'запись', 'мыть', 'телефон', 'друг'],
#   ['мочь',
#    'узнать',
#    'войти',
#    'учётный',
#    'запись',
#    'указать',
#    'свой',
#    'адрес',
#    'имя',
#    'устройство'],
#   '0'],
#  [['мочь', 'зарабатывать', 'деньга', 'интернет'],
#   ['разный',
#    'способ',
#    'заработать',
#    'деньга',
#    'интернет',
#    'исключая',
#    'продажа',
#    'вещий'],
#   '0'],
#  [['цель', 'жизнь'],
#   ['каков', 'цель', 'жизнь', 'самый', 'дело', 'являться', 'жизнь'],
#   '1'],
#  [['правительство',
#    'вывести',
#    'мусульманин',
#    'христиана',
#    'индийский',
#    'гражданство',
#    'поместить',
#    'лодка',
#    'ронингие'],
#   ['почему',
#    'индия',
#    'применять',
#    'модель',
#    'депортация',
#    'незаконный',
#    'бангладеш'],
#   '0'],
#  [['правильный',
#    'этикет',
#    'желающий',
#    'засвидетельствовать',
#    'день',
#    'рождение',
#    'джедай'],
#   ['насколько',
#    'важный',
#    'пожелать',
#    'кома',
#    'счастливый',
#    'день',
#    'рождение'],
#   '0'],
#  [['хотеть',
#    'открыть',
#    'коммерческий',
#    'радиостанция',
#    'любой',
#    'город',
#    'индия',
#    'сколько',
#    'стоить',
#    'каков',
#    'процедура'],
#   ['хотеть',
#    'сделать',
#    'туристический',
#    'видеоролик',
#    'путешествие',
#    'индия',
#    'новый',
#    'зеландия',
#    'сколько',
#    'стоить'],
#   '0'],
#  [['почему', 'швейцарец', 'презирать', 'азиат'],
#   ['почему', 'технический', 'сотрудник', 'сильно', 'презирать', 'продавец'],
#   '0'],
#  [['каков',
#    'некоторый',
#    'высокооплачиваемый',
#    'работа',
#    'область',
#    'биотехнология'],
#   ['каков',
#    'некоторый',
#    'высокооплачиваемый',
#    'рабочий',
#    'место',
#    'свежий',
#    'технология',
#    'область',
#    'биотехнология'],
#   '1'],
#  [['мочь', 'увеличить', 'свой', 'рост', 'год'],
#   ['мочь', 'увеличить', 'рост'],
#   '1'],
#  [['каков',
#    'основной',
#    'последствие',
#    'землетрясение',
#    'камбоджа',
#    'эффект',
#    'сравниваться',
#    'землетрясение',
#    'камчатка',
#    'год'],
#   ['каков',
#    'основной',
#    'последствие',
#    'землетрясение',
#    'камбоджа',
#    'эффект',
#    'сравниваться',
#    'землетрясение',
#    'вальпараисо',
#    'год'],
#   '1'],
#  [['разница', 'искренность', 'честность'],
#   ['разница', 'честной', 'искренний'],
#   '0'],
#  [['который', 'являться', 'хороший', 'игровой', 'ноутбук'],
#   ['который', 'являться', 'хороший', 'игровой', 'ноутбук'],
#   '1'],
#  [['каков', 'ваш', 'обзор', 'следующий', 'воин', 'полигон', 'часть'],
#   ['каков', 'ваш', 'обзор', 'следующий', 'воин', 'полигон', 'часть'],
#   '0'],
#  [['являться', 'хороший', 'справочник', 'класс', 'физика', 'го'],
#   ['книга', 'должный', 'выбрать', 'справка', 'физика', 'химия', 'класс'],
#   '0'],
#  [['национальный',
#    'институт',
#    'технология',
#    'курукшетр',
#    'социальный',
#    'жизнь',
#    'нитка',
#    'сураткале'],
#   ['национальный',
#    'институт',
#    'технология',
#    'выпускной',
#    'часть',
#    'урок',
#    'хотеть',
#    'дать',
#    'свой',
#    'юниор',
#    'прежде',
#    'покинуть'],
#   '0'],
#  [['хороший', 'романтический', 'фильм', 'английский', 'язык'],
#   ['хороший', 'романтический', 'фильм', 'либо', 'видеть'],
#   '1'],
#  [['вызывать', 'кошмар'],
#   ['вызывать', 'кошмар', 'который', 'казаться', 'реальный'],
#   '1'],
#  [['абстрактный', 'экспрессионизм', 'живопись'],
#   ['каков',
#    'некоторый',
#    'основный',
#    'влияние',
#    'абстрактный',
#    'экспрессионизм'],
#   '0'],
#  [['работать', 'печать'], ['работать', 'печать'], '1'],
#  [['каков', 'посещение', 'катех', 'джерий', 'эрхардт'],
#   ['который', 'являться', 'известный', 'человек', 'который', 'посещать'],
#   '0'],
#  [['почему', 'гарри', 'стать', 'хрусткать'], ['хоркрукс'], '0'],
#  [['хороший',
#    'программный',
#    'продукт',
#    'программа',
#    'менеджер',
#    'продукт',
#    'который',
#    'ранний',
#    'ти',
#    'мочь',
#    'присоединиться',
#    'изучить',
#    'управление',
#    'продукт',
#    'получить',
#    'достойный',
#    'карьер',
#    'компания'],
#   ['каков',
#    'общий',
#    'требование',
#    'стать',
#    'менеджер',
#    'продукт',
#    'менеджер',
#    'программа',
#    'компания',
#    'основать',
#    'продукт'],
#   '0']]

# %%
### реализуйте эту функцию ранжирования 
from math import log

k = 2.0
b = 0.75
N = len(all)

l = 0
for i in normal:
    l += len(i[1])
avgdl = l/N

def bm25(D, Q) -> float:
    score = 0
    for q in Q:
        n = 0
        for doc in normal:
            if q in doc[1]:
                n += 1
        IDF = log((N - n + 0.5)/(n+0.5))
        TF = 0
        for word in D:
            if word == q:
                TF += 1
        TF = TF/len(D)
        score += IDF*((TF*(k + 1))/(TF + (k*(1 - b + (b*(len(D)/avgdl))))))
    return score

# %%
bm25(normal[4][1], normal[4][0])
# Out:
# 4.666286533192796

# %%
bm = {}

# %%
from operator import itemgetter

# %%
for z in range(len(all)):
    band = {}
    for i in range(len(all)):
        try:
            band[all[i][2]] = bm25(normal[i][1], normal[z][0])
        except ZeroDivisionError:
            pass
    query = all[z][1]
    bm[query] = sorted(band.items(), key=itemgetter(1))[-10:]

# %%
bm
# Out:
# {'5 фактов о земной коре': [('в чем разница между астероидами и кометами',
#    0.0),
#   ('почему нерафинированное молоко хорошо для вас', 0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('как земное ядро \u200b\u200bвлияет на его корку', 2.400088683911345),
#   ('какие интересные факты о Facebook', 5.683407772417998)],
#  'daniel ek: когда мы ожидаем выявить в Индии': [('почему Индия не применяет модель burma-rohingya для депортации незаконных бангладеш',
#    0.6130685243427562),
#   ('как демонизация может повлиять на gdp Индии как в краткосрочной, так и в долгосрочной перспективе',
#    0.6130685243427562),
#   ('может нарэндра modi стать премьер-министром Индии в 2019 году',
#    0.6130685243427562),
#   ('daniel ek: существуют ли какие-либо планы на будущее в области выделения в Индии?',
#    0.6130685243427562),
#   ('какова наилучшая настройка домашней беспроводной сети и ожидаемые скорости',
#    0.6747818627182138),
#   ('каковы ваши взгляды на запрет на 500 и 1000 рупий в Индии?',
#    0.791797101302783),
#   ('кто победит, если начнется война между Индией и Пакистаном',
#    1.0590440734033473),
#   ('когда я могу ожидать знакомой почты подтверждения', 1.464132129679536),
#   ('будет ли ядерная война между Индией и Пакистаном', 1.4814092879175873),
#   ('как я могу получить доступ к google com из Индии', 1.4814092879175873)],
#  'does fab в настоящее время предлагает новые варианты акций сотрудников или rsus': [('действительно ли крикетцы пьют чай во время перерыва на чай',
#    0.6130685243427562),
#   ('как я могу держать нос от душного в ночное время', 0.791797101302783),
#   ('как мне разорвать мой график времени на 4 месяца, чтобы взломать ворота 2016',
#    0.791797101302783),
#   ('каково ваше творческое разрешение нового года на 2017 год',
#    0.8042164269268487),
#   ('почему технические сотрудники так сильно презирают продавцов',
#    1.169474507391589),
#   ('как президентство козыря повлияет на учеников в настоящее время в нас или планирует учиться у нас',
#    1.208985237519587),
#   ('если пространство расширяется, где новое пространство исходит из',
#    1.3892421594854605),
#   ('какая величайшая тайна всех времен', 2.1963289715523273),
#   ('какая смешная шутка всех времен', 2.1963289715523273),
#   ('В настоящее время uber предлагает новые варианты опционов на акции или rsus',
#    5.302547897366337)],
#  'im в любви с моим бисексуальным лучшим другом, который также является парнем и имеет подругу, и я хочу рассказать ему, как я могу двигаться дальше': [('который является лучшим игровым ноутбуком под rs 60000',
#    2.0588524397174064),
#   ('которые являются одними из лучших художественных романов',
#    2.0588524397174064),
#   ('который является лучшим языком программирования', 2.0588524397174064),
#   ('который является лучшим общежитием не девочек в srm', 2.0588524397174064),
#   ('который является лучшим наушниками под RS 1000', 2.8799586374603385),
#   ('которые являются ронингами', 3.0201257613787624),
#   ('в чем разница между любовью и жалостью', 3.243950676063185),
#   ('зачем нам нужны друзья?', 3.5853509277733133),
#   ('то, что вызывает любовь в любви, означает', 3.845931000330041),
#   ('который является sandeep maheshwari', 4.823743743089911)],
#  'Гарвардский колледж: что такое общий совет по шопингу для турецких классов': [('если пространство расширяется, где новое пространство исходит из',
#    0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('имеет значение, из какого колледжа вы делаете свой выпускной bcom для поступления в высшую индийскую школу, даже если я нахожу высокий 99 +',
#    0.3112640128535677),
#   ('каково общее требование стать менеджером продукта или менеджером программ в компании, основанной на продуктах',
#    0.3841602510431604),
#   ('имеет какой-либо сотрудник по приему колледжа, публично публичный, читая эссе участника',
#    0.43255818008358216),
#   ('каковы некоторые советы о том, чтобы сделать это через процесс собеседования на дому в медицинской медицине',
#    0.5870428997890438),
#   ('Я изучаю колледж asutosh в kolkata, могу ли я учиться в любом другом колледже в Индии на моем 2-м году',
#    0.7106475130097443),
#   ('каковы плюсы и минусы общей инициативы по основным стандартам',
#    0.8475693757492804),
#   ('какую книгу я должен выбрать для справки для физики и химии класса 11 cbse board',
#    0.9932561107441449),
#   ('курсы Гарвардского колледжа: что такое общий совет по шопингу для уроков тамила',
#    3.617484241197146)],
#  'Дональдский козырь принимает кокаин, поскольку': [('почему нерафинированное молоко хорошо для вас',
#    0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('теперь сторонники козыря ожидают, что президент выполнит свои обещания, которые он так решительно продал на',
#    0.45587612288605295),
#   ('как президентство козыря повлияет на учеников в настоящее время в нас или планирует учиться у нас',
#    0.6747818627182138),
#   ('есть ли какие-либо сильные признаки того, что козырь Donald кокаина',
#    3.1799305366894917)],
#  'Израиль против Ирана: кто победит': [('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('Какова позиция Пакистана, обладающего оружием массового уничтожения северной кореей, поддерживает ли он dprk или против dprk',
#    0.4104148263648886),
#   ('как могли конфедераты, возможно, победить профсоюзные силы в Gettysburg во время американской гражданской войны',
#    0.45587612288605295),
#   ('каково распределение трафика между результатами поиска Google, например, 1 против 2 в рейтинге первой страницы против второй страницы',
#    0.8001421928738006),
#   ('который является лучшим графическим дизайнером в Израиле',
#    1.169474507391589),
#   ('кто победит, если начнется война между Индией и Пакистаном',
#    1.464132129679536),
#   ('если Израиль и Иран отправятся на войну, кто победит', 4.744125510391157)],
#  'Какова идеальная жизнь после выхода на пенсию': [('какие уроки жизни вы можете узнать у темного рыцаря',
#    0.9244236259649562),
#   ('как я отказываюсь выбирать между разными вещами в моей жизни',
#    1.2364346380927809),
#   ('если вы мечтаете о каком-то вреде, будут раны в реальной жизни',
#    1.2364346380927809),
#   ('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('Какова цель жизни, что на самом деле является жизнью', 1.7356761540837198),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877),
#   ('в чем смысл жизни', 4.0955640263527595),
#   ('что такое жизнь после выхода на пенсию', 9.68093111124735)],
#  'Какова история кохинор кох-и-ноор-бриллиант': [('каково это - работать с исполнительным рекрутером',
#    0.9216374400126335),
#   ('каковы преимущества перечисления компании в nse', 0.9216374400126335),
#   ('какова программа для карты географии icse 2017', 0.9216374400126335),
#   ('каков ваш список ведер', 0.9216374400126335),
#   ('какова основная платформа данных', 0.9216374400126335),
#   ('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('что произойдет, если правительство Индии украдет кохинор кох-и-ноор-алмаз назад',
#    1.931819157916543),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877)],
#  'Каково было посещение катеха с джерием эрхардтом': [('какова структура веб-приложений',
#    0.9216374400126335),
#   ('каково это - работать с исполнительным рекрутером', 0.9216374400126335),
#   ('каковы преимущества перечисления компании в nse', 0.9216374400126335),
#   ('какова программа для карты географии icse 2017', 0.9216374400126335),
#   ('каков ваш список ведер', 0.9216374400126335),
#   ('какова основная платформа данных', 0.9216374400126335),
#   ('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877)],
#  'Каково это - жить в одеколоне': [('каково это - работать с исполнительным рекрутером',
#    0.9216374400126335),
#   ('каковы преимущества перечисления компании в nse', 0.9216374400126335),
#   ('какова программа для карты географии icse 2017', 0.9216374400126335),
#   ('каков ваш список ведер', 0.9216374400126335),
#   ('какова основная платформа данных', 0.9216374400126335),
#   ('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('каково это быть пожарным', 2.1824366012104877),
#   ('ты бы жил в крошечном доме', 2.8811197569657176),
#   ('каково это жить в k ln germany', 6.784160005738987)],
#  'Каково это быть дорси': [('каково это - работать с исполнительным рекрутером',
#    0.9216374400126335),
#   ('каковы преимущества перечисления компании в nse', 0.9216374400126335),
#   ('какова программа для карты географии icse 2017', 0.9216374400126335),
#   ('каков ваш список ведер', 0.9216374400126335),
#   ('какова основная платформа данных', 0.9216374400126335),
#   ('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877),
#   ('что такое дом-дорси', 5.683407772417998)],
#  'Каковы лучшие каналы YouTube для изучения медицины?': [('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('что произойдет, если глазная медицина попадет в глаза',
#    1.5641949737016652),
#   ('какие хорошие книги для самостоятельного изучения исчисления',
#    1.9918253745336938),
#   ('что похоже на 4shared, но лучше', 1.995995633252668),
#   ('почему натриевые каналы не проходят через калиевые каналы',
#    2.1784558720876714),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877),
#   ('какие уловки для эффективного изучения', 2.8811197569657176),
#   ('какие из лучших каналов YouTube для изучения git', 7.374754942124422)],
#  'Каковы наилучшие способы изучения французского языка?': [('который является лучшим языком программирования',
#    1.9918253745336938),
#   ('что похоже на 4shared, но лучше', 1.995995633252668),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877),
#   ('лучший способ стать миллиардером', 2.392317053350821),
#   ('какой лучший способ прыгать с веревкой', 2.392317053350821),
#   ('что было бы лучшим способом удержаться в тюрьме', 2.392317053350821),
#   ('какие уловки для эффективного изучения', 2.8811197569657176),
#   ('как я изучаю французский полы', 3.558357810878418),
#   ('какие из лучших каналов YouTube для изучения git', 4.130804266061237)],
#  'Кристен Стюарт - плохая актриса, почему или почему': [('насколько плоха новая книга jk rowling',
#    1.9432961195040126),
#   ('почему я всегда впадаю в депрессию', 2.761093214816075),
#   ('почему китайская поддержка masood azhar', 2.761093214816075),
#   ('почему в Керале так много христиан', 2.761093214816075),
#   ('почему творчество важно', 2.761093214816075),
#   ('почему нерафинированное молоко хорошо для вас', 2.761093214816075),
#   ('как вы не получаете плохих снов?', 2.8811197569657176),
#   ('Дженнифер Лоуренс - плохая актриса', 4.343384803415358),
#   ('почему мы плачем', 4.410017056036992),
#   ('почему мы засыпаем', 4.410017056036992)],
#  'Мне 19 лет, как я могу улучшить свои навыки или что я должен сделать, чтобы стать предпринимателем в ближайшие несколько лет': [('мне почти 40 лет, мне слишком поздно изучать фортепиано',
#    2.0746201690917845),
#   ('может нарэндра modi стать премьер-министром Индии в 2019 году',
#    2.1505802296119616),
#   ('какой штатив я должен получить для своего canon 6d', 2.228942045045792),
#   ('каково ваше творческое разрешение нового года на 2017 год',
#    2.2723273560430313),
#   ('как я могу стать миллиардером в финансах', 2.2946139499819265),
#   ('что я могу сделать, чтобы сделать мир лучше', 2.3696590411964515),
#   ('у rahul gandhi есть шансы стать следующим pm of india после modi',
#    2.4862326773413543),
#   ('что я могу сделать, чтобы не ревновать кого-то', 3.1120778653929366),
#   ('Я 19-летний парень, как я могу стать миллиардером в ближайшие 10 лет',
#    3.1438363403561063),
#   ('как я могу улучшить свою концентрацию', 3.80914667453718)],
#  'Можете ли вы дебезать петухи в возрасте 8 месяцев?': [('может увеличить рост после 25',
#    0.9157488938406094),
#   ('как я могу просмотреть удаленные instagram dms', 0.9157488938406094),
#   ('могу я заработать деньги на quora', 0.9157488938406094),
#   ('как мне разорвать мой график времени на 4 месяца, чтобы взломать ворота 2016',
#    1.0946622575196623),
#   ('как я могу лучше всего инвестировать 5000 в течение следующих 6 месяцев',
#    1.4247982840693396),
#   ('может быть взломан', 1.4626337927360094),
#   ('как я могу писать в narendra modi', 1.4626337927360094),
#   ('как я могу присоединиться к', 1.4626337927360094),
#   ('здорово ли потерять 13 фунтов в месяц', 2.048053513651783),
#   ('в каком возрасте, как и где вы потеряли свою девственность',
#    2.400088683911345)],
#  'Свами вивекананда когда-либо ел без овощей или яйца во время своего путешествия по миру': [('какое самое вкусное блюдо вы когда-либо ели и почему',
#    1.0373100845458922),
#   ('какой лучший романтический фильм вы когда-либо видели',
#    1.0373100845458922),
#   ('кто-нибудь когда-либо имел почти смертельный опыт', 1.0373100845458922),
#   ('есть ли какие-либо сильные признаки того, что козырь Donald кокаина',
#    1.0373100845458922),
#   ('почему США - самая могущественная страна мира', 1.0386705733154709),
#   ('что я могу сделать, чтобы сделать мир лучше', 1.3892421594854605),
#   ('что самое лучшее, что вы когда-либо узнали о quora', 1.4510074059133162),
#   ('какой лучший веб-сайт путешествия', 2.1880231619719566),
#   ('какая величайшая тайна всех времен', 2.1963289715523273),
#   ('какая смешная шутка всех времен', 2.1963289715523273)],
#  'Что такое cpagrip com': [('у rahul gandhi есть шансы стать следующим pm of india после modi',
#    0),
#   ('хорошо делать спортзал утром и плавать в полдень', 0),
#   ('в чем разница между астероидами и кометами', 0),
#   ('почему нерафинированное молоко хорошо для вас', 0),
#   ('какие уловки для эффективного изучения', 0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0),
#   ('что это за картина?', 0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0),
#   ('если пространство расширяется, где новое пространство исходит из', 0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0)],
#  'Я хочу симулировать поддельное местоположение для приложения, работающего на моем устройстве ios, как вы подделываете местоположение gps для ios без джейлбрейка в качестве некодера': [('какие полезные приложения для телефонов Android недоступны в игровом магазине google',
#    1.0946622575196623),
#   ('как сделать снимок экрана на моем macbook pro, какие инструкции',
#    1.5641949737016652),
#   ('каково это - работать с исполнительным рекрутером', 1.6769474099021338),
#   ('как работают здания, устойчивые к землетрясениям', 1.6769474099021338),
#   ('какова структура веб-приложений', 2.048053513651783),
#   ('какие хорошие качества лидера', 3.243950676063185),
#   ('как добавить второе устройство в аккаунт Google Play', 3.243950676063185),
#   ('как работают 3D-печать', 3.9710099077847527),
#   ('где работают ученые', 3.9710099077847527),
#   ('как я могу подделать свое местоположение iphone без джейлбрейка',
#    5.147395221029868)],
#  'астрология: я - луна-колпачок из козерога и крышка, поднимающая то, что это говорит обо мне': [('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('как я могу научиться свободно говорить по-английски', 1.329322118058481),
#   ('как я могу говорить с большей ясностью и уверенностью', 1.329322118058481),
#   ('как я могу свободно говорить по-китайски', 1.8594789223432986),
#   ('что правильно: говорить или говорить с', 4.578129325371843),
#   ('Я тройная луна-козерог и восхождение в козероге, что это говорит обо мне',
#    4.666286533192796)],
#  'безопасно ли потерять 25 фунтов за 1 месяц': [('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('я потерял весь свой идентификатор, я принят, и не могу получить доступ к моему оригинальному свидетельству о рождении, как я могу заменить свой идентификатор без свидетельства о рождении',
#    0.19277033044071112),
#   ('как я могу лучше всего инвестировать 5000 в течение следующих 6 месяцев',
#    1.0946622575196623),
#   ('как мне разорвать мой график времени на 4 месяца, чтобы взломать ворота 2016',
#    1.0946622575196623),
#   ('в каком возрасте, как и где вы потеряли свою девственность',
#    2.048053513651783),
#   ('здорово ли потерять 13 фунтов в месяц', 6.49619571121491)],
#  'будет играть blu ray на обычном dvd-игроке, если да, то как': [('в чем разница между астероидами и кометами',
#    0.0),
#   ('почему нерафинированное молоко хорошо для вас', 0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('который является самым богатым игроком всех времен и как я могу достичь его уровня в качестве игрока',
#    0.8776928215447433),
#   ('как вы можете играть на Blu-ray DVD на обычном DVD-плеере',
#    4.80017736782269)],
#  'будет ли еще один джекпот на лотерею на миллиард долларов': [('почему нерафинированное молоко хорошо для вас',
#    0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('почти две недели на prozac, почему я до сих пор чувствую себя антисоциальным и все еще не хочу участвовать в событиях, почему меняется мое социальное поведение и настроение ежедневно',
#    0.2059447886169722),
#   ('как мне пережить кого-то, кого я любил сейчас, когда мы расстались в прошлом году, и я все еще скучаю по ней',
#    0.905494613864297),
#   ('когда лотерея достигнет джекпота в следующем миллиарде долларов',
#    5.1312848604101235)],
#  'будет ли недавняя демонизация на более высоком уровне gdp, если да, сколько': [('сколько времени требуется, чтобы научиться разработке приложений для Android с нуля',
#    0.6265909223433984),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.6402669493698329),
#   ('сколько в среднем стоило бы на видеоленту 2-часовую презентацию',
#    0.8092616996542472),
#   ('сколько и с чем я должен кормить своего 3-месячного ворона',
#    0.8092616996542472),
#   ('как демонизация может повлиять на gdp Индии как в краткосрочной, так и в долгосрочной перспективе',
#    0.9932561107441449),
#   ('сколько раз в день перекрывают руки часы', 1.0824033144867713),
#   ('что такое хорошие альпинистские институты для начинающего уровня альпинизма',
#    1.169474507391589),
#   ('сколько четырехзначных чисел можно сформировать, используя 0 1 2 3 4 5 6 и 7, сколько из них составляет от 4000 до 6000',
#    1.1855542033299895),
#   ('достаточно 3 8 гпа, чтобы попасть в высшую школу', 1.3892421594854605),
#   ('сколько денег я должен поднять', 1.5140846010313136)],
#  'были ли там рабы с именем reddice': [('какие уловки для эффективного изучения',
#    0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('как я могу узнать, кто вошел в мою учетную запись gmail, указав свой IP-адрес или имя устройства',
#    0.45587612288605295),
#   ('люди говорят, не пытайтесь угодить другим, потому что это приятно другим людям, которые им нравятся',
#    0.5494892807687253),
#   ('в древних римских рабах заклеймили то, что произошло с маркой, если они впоследствии были освобождены',
#    0.790768552688298),
#   ('что это за модельное имя, я вижу ее везде', 2.048053513651783)],
#  'в игре изюм на солнце, почему walter и beneatha спорят': [('какая игра престола злодея вам больше всего понравится быть во власти',
#    1.169474507391589),
#   ('почему я всегда впадаю в депрессию', 1.3805466074080375),
#   ('почему китайская поддержка masood azhar', 1.3805466074080375),
#   ('почему в Керале так много христиан', 1.3805466074080375),
#   ('почему творчество важно', 1.3805466074080375),
#   ('почему нерафинированное молоко хорошо для вас', 1.3805466074080375),
#   ('почему мы плачем', 2.205008528018496),
#   ('почему мы засыпаем', 2.205008528018496),
#   ('есть ли игра для монстров-охотников', 3.243950676063185),
#   ('в изюминке на солнце, почему walter и beneatha спорят',
#    5.731346875263054)],
#  'в какой год пришла буква j': [('сколько человек может измениться от рождения до смерти в течение примерно 70 лет',
#    0.38930282365705987),
#   ('как тринадцать лет, что самое лучшее, что я могу сделать для своего здоровья',
#    0.4780702621555538),
#   ('Я 19-летний парень, как я могу стать миллиардером в ближайшие 10 лет',
#    0.6004869663023032),
#   ('может нарэндра modi стать премьер-министром Индии в 2019 году',
#    0.6004869663023032),
#   ('как мне пережить кого-то, кого я любил сейчас, когда мы расстались в прошлом году, и я все еще скучаю по ней',
#    0.6004869663023032),
#   ('какие самые интересные продукты и инновации выходят в 2016 году',
#    0.7755476270747867),
#   ('какие книги стоит читать в начале 20-х годов', 0.7755476270747867),
#   ('мне почти 40 лет, мне слишком поздно изучать фортепиано',
#    1.0373100845458922),
#   ('каково ваше творческое разрешение нового года на 2017 год',
#    1.1361636780215156),
#   ('когда была создана буква j', 5.683407772417998)],
#  'в каком возрасте кто-то потеряет свою девственность': [('как я переношу свои контакты с одного телефона Android на другой Android-телефон',
#    0.7173609402164626),
#   ('как я начинаю свое продолжение за дар магии', 0.7173609402164626),
#   ('как я могу забыть свою жену', 1.0034569724854305),
#   ('какой штатив я должен получить для своего canon 6d', 1.0034569724854305),
#   ('где я могу опубликовать свою статью', 1.0034569724854305),
#   ('как я могу улучшить свою концентрацию', 1.0034569724854305),
#   ('как я могу поддерживать свое спокойствие', 1.0034569724854305),
#   ('вы когда-нибудь сожалели о своем разводе', 1.0034569724854305),
#   ('здорово ли потерять 13 фунтов в месяц', 2.048053513651783),
#   ('в каком возрасте, как и где вы потеряли свою девственность',
#    7.851687853959904)],
#  'в которых чудесные фильмы не включали камеи stan lee': [('который владеет природными факторами',
#    0.9216374400126335),
#   ('какой лучший романтический фильм вы когда-либо видели',
#    1.1988322405905878),
#   ('как я могу заказать ronda rousey для просмотра в фильме для взрослых',
#    1.1988322405905878),
#   ('какие лучшие женские сильные персонажи в фильмах', 1.1988322405905878),
#   ('каков лучший фильм о триллере в голливуде', 1.1988322405905878),
#   ('которые являются ронингами', 1.3664144185382459),
#   ('которые были создателями тригонометрии', 1.3664144185382459),
#   ('есть ли какой-нибудь хороший фильм об инцесте', 1.6769474099021338),
#   ('который является sandeep maheshwari', 2.1824366012104877),
#   ('есть ли какие-нибудь фильмы на телевидении', 2.4862326773413543)],
#  'в операционной, когда два хирурга с равным опытом не согласны с хирургической процедурой, как нарушается связь': [('какие уловки для эффективного изучения',
#    0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('почему всегда ожидалось, что женщина должна заботиться о домашнем хозяйстве детей и приготовлении пищи, особенно в индийской культуре, - эти виды деятельности несут ответственность только для женщин, почему мужчины не имеют равного участия в такой работе',
#    0.10478269044349652),
#   ('врачи: как хирурги проводят на операциях более 6 часов, они отдыхают во время операции',
#    0.790768552688298),
#   ('кто-нибудь когда-либо имел почти смертельный опыт', 1.5641949737016652),
#   ('какой был ваш первый сексуальный опыт', 3.243950676063185)],
#  'в чем разница между деизмом и агностицизмом': [('может лысый человек когда-либо вырастить свои волосы назад',
#    0.0),
#   ('кажется, есть разница между моей недельной зарплатой и годовой зарплатой, которую мой работодатель согласился с тем, как это работает',
#    0.36284613314731223),
#   ('в чем разница между свадьбой в китайском и западном стиле',
#    1.1653487756886685),
#   ('какая именно разница между морем и заливом', 1.6301101562475597),
#   ('в чем разница между честным и искренним', 2.41679203187727),
#   ('в чем разница между любовью и жалостью', 2.41679203187727),
#   ('какая разница между хобби и привычкой', 2.41679203187727),
#   ('какая разница между оффшорными и наземными', 2.41679203187727),
#   ('в чем разница между астероидами и кометами', 2.41679203187727),
#   ('в чем разница между', 6.696908552397746)],
#  'в чем разница между заливом залива и проливами': [('может лысый человек когда-либо вырастить свои волосы назад',
#    0.0),
#   ('кажется, есть разница между моей недельной зарплатой и годовой зарплатой, которую мой работодатель согласился с тем, как это работает',
#    0.36284613314731223),
#   ('в чем разница между свадьбой в китайском и западном стиле',
#    1.1653487756886685),
#   ('в чем разница между честным и искренним', 2.41679203187727),
#   ('в чем разница между любовью и жалостью', 2.41679203187727),
#   ('какая разница между хобби и привычкой', 2.41679203187727),
#   ('какая разница между оффшорными и наземными', 2.41679203187727),
#   ('в чем разница между астероидами и кометами', 2.41679203187727),
#   ('какая именно разница между морем и заливом', 6.43028752407025),
#   ('в чем разница между', 6.696908552397746)],
#  'в чем разница между китайской свадебной церемонией и западной свадебной церемонией': [('какая именно разница между морем и заливом',
#    1.6301101562475597),
#   ('в чем разница между честным и искренним', 2.41679203187727),
#   ('в чем разница между любовью и жалостью', 2.41679203187727),
#   ('какая разница между хобби и привычкой', 2.41679203187727),
#   ('какая разница между оффшорными и наземными', 2.41679203187727),
#   ('в чем разница между астероидами и кометами', 2.41679203187727),
#   ('как вы думаете о китайской кухне?', 3.0364324727881624),
#   ('почему китайская поддержка masood azhar', 3.0364324727881624),
#   ('в чем разница между свадьбой в китайском и западном стиле',
#    4.34527931237816),
#   ('в чем разница между', 6.696908552397746)],
#  'в чем разница между любовью и жалостью': [('кажется, есть разница между моей недельной зарплатой и годовой зарплатой, которую мой работодатель согласился с тем, как это работает',
#    0.36284613314731223),
#   ('в чем разница между свадьбой в китайском и западном стиле',
#    1.1653487756886685),
#   ('какая именно разница между морем и заливом', 1.6301101562475597),
#   ('в чем разница между честным и искренним', 2.41679203187727),
#   ('какая разница между хобби и привычкой', 2.41679203187727),
#   ('какая разница между оффшорными и наземными', 2.41679203187727),
#   ('в чем разница между астероидами и кометами', 2.41679203187727),
#   ('то, что вызывает любовь в любви, означает', 3.845931000330041),
#   ('в чем разница между', 6.696908552397746),
#   ('в чем разница между любовью и жалостью', 9.219100518818873)],
#  'в чем разница между нейтральным состоянием и буферным состоянием': [('может лысый человек когда-либо вырастить свои волосы назад',
#    0.0),
#   ('кажется, есть разница между моей недельной зарплатой и годовой зарплатой, которую мой работодатель согласился с тем, как это работает',
#    0.36284613314731223),
#   ('в чем разница между свадьбой в китайском и западном стиле',
#    1.1653487756886685),
#   ('какая именно разница между морем и заливом', 1.6301101562475597),
#   ('в чем разница между честным и искренним', 2.41679203187727),
#   ('в чем разница между любовью и жалостью', 2.41679203187727),
#   ('какая разница между хобби и привычкой', 2.41679203187727),
#   ('какая разница между оффшорными и наземными', 2.41679203187727),
#   ('в чем разница между астероидами и кометами', 2.41679203187727),
#   ('в чем разница между', 6.696908552397746)],
#  'вам нужны друзья': [('почему эмоционально оскорбительные люди в моей жизни несколько бывших друзей друзей и прошлых коллег боссы были обидчиками, я их привлекаю',
#    0.35942676852774585),
#   ('я девушка, и я люблю своего лучшего друга, который тоже девушка, что я должен делать',
#    0.40622632802218556),
#   ('какие автомобильные услуги доступны в атланте, насколько хороши они по сравнению с такси и относительно друг друга',
#    0.5536883676193808),
#   ('какие хорошие лирические песни, чтобы отправить своих лучших друзей',
#    0.6265909223433984),
#   ('мне нужен автомобиль с четырьмя колесами, чтобы проехать весь путь по дороге к хане',
#    0.6747818627182138),
#   ('если каждое государство США объявит войну друг другу, которая выиграет',
#    0.7834783016528083),
#   ('я мог бы нанять двух частных следователей, а затем заставить их следовать друг за другом',
#    0.7834783016528083),
#   ('что я должен делать, когда мой лучший друг игнорирует меня',
#    1.0824033144867713),
#   ('нам нужна секция ipc 375', 4.849788816489621),
#   ('зачем нам нужны друзья?', 8.435139744262933)],
#  'влияет ли познание на восприятие': [('в чем разница между астероидами и кометами',
#    0.0),
#   ('почему нерафинированное молоко хорошо для вас', 0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('влияет ли когнитивный штамм на пищеварение', 2.1880231619719566),
#   ('как земное ядро \u200b\u200bвлияет на его корку', 2.1880231619719566)],
#  'возможно ли преследовать много разных вещей в жизни?': [('Я хочу установить exe файлы расширения в Android-мобиль, это возможно',
#    1.0386705733154709),
#   ('если вы мечтаете о каком-то вреде, будут раны в реальной жизни',
#    1.2364346380927809),
#   ('Какова цель жизни, что на самом деле является жизнью', 1.3542644065430807),
#   ('какие-то разные способы заработать деньги в Интернете, исключая продажи вещей',
#    1.441796647465006),
#   ('возможно ли хранить энергию молнии', 1.9432961195040126),
#   ('возможно ли путешествовать быстрее, чем свет', 1.9432961195040126),
#   ('почему люди собирают вещи', 2.1880231619719566),
#   ('что такое жизнь после выхода на пенсию', 2.5642154894905134),
#   ('как я отказываюсь выбирать между разными вещами в моей жизни',
#    2.800629611794446),
#   ('в чем смысл жизни', 4.0955640263527595)],
#  'всегда полезен': [('в чем разница между астероидами и кометами', 0.0),
#   ('почему нерафинированное молоко хорошо для вас', 0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('почему программы карьеры могут быть более полезными, чем высшее образование, если вообще начинающим предпринимателям и магнатам',
#    0.4104148263648886),
#   ('какие полезные приложения для телефонов Android недоступны в игровом магазине google',
#    1.169474507391589)],
#  'вы когда-нибудь слышали о взломе путешествия': [('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('Я хочу сделать туристический видеоролик о путешествиях для Индии и Новой Зеландии, сколько это будет стоить',
#    0.48703195947557193),
#   ('кто-нибудь когда-либо имел почти смертельный опыт', 1.3892421594854605),
#   ('как повысить скорость интернета путем взлома через dns',
#    1.715798407009956),
#   ('есть ли какой-нибудь хороший фильм об инцесте', 1.9432961195040126),
#   ('вы когда-нибудь сожалели о своем разводе', 1.9432961195040126),
#   ('какой лучший веб-сайт путешествия', 2.1880231619719566),
#   ('есть ли какие-нибудь фильмы на телевидении', 2.8811197569657176)],
#  'вы можете подняться, если кто-то коснется сорняков, а затем вы пожимаете им руку, а затем вы едите что-то с той же рукой': [('может увеличить рост после 25',
#    0.9157488938406094),
#   ('как я могу просмотреть удаленные instagram dms', 0.9157488938406094),
#   ('могу я заработать деньги на quora', 0.9157488938406094),
#   ('если кто-то схватит вас за вашу рубашку обеими руками и скажет вам заткнуться, это нападение, и вы можете позвонить в полицию',
#    0.9366874325760303),
#   ('я мог бы нанять двух частных следователей, а затем заставить их следовать друг за другом',
#    1.2646974456393523),
#   ('может быть взломан', 1.4626337927360094),
#   ('как я могу писать в narendra modi', 1.4626337927360094),
#   ('как я могу присоединиться к', 1.4626337927360094),
#   ('что это за модельное имя, я вижу ее везде', 2.048053513651783),
#   ('сколько раз в день перекрывают руки часы', 3.1283899474033303)],
#  'вы нашли окончание романного упадка 1984 года?': [('какие самые интересные продукты и инновации выходят в 2016 году',
#    0.7755476270747867),
#   ('какие книги стоит читать в начале 20-х годов', 0.7755476270747867),
#   ('где я могу найти вкусные кексы на золотом побережье', 0.9244236259649562),
#   ('мне почти 40 лет, мне слишком поздно изучать фортепиано',
#    1.0373100845458922),
#   ('каково ваше творческое разрешение нового года на 2017 год',
#    1.1361636780215156),
#   ('найти остаток, когда математика 23 ^ 24 математика разделена на 24 23',
#    1.2364346380927809),
#   ('где я могу найти диаграмму преобразования для cc to horsepower',
#    1.7295462981889127),
#   ('как я могу найти хорошего эскорта', 1.7295462981889127),
#   ('как я могу найти работу в Японии', 1.7295462981889127),
#   ('как бы вы нашли нуль функции для математики y = frac 4x ^ 2 - 36x x - 9 math',
#    1.7295462981889127)],
#  'вы сожалеете о своем разводе': [('как я могу держать свою собаку от блох',
#    0.7173609402164626),
#   ('как я переношу свои контакты с одного телефона Android на другой Android-телефон',
#    0.7173609402164626),
#   ('как я начинаю свое продолжение за дар магии', 0.7173609402164626),
#   ('в каком возрасте, как и где вы потеряли свою девственность',
#    1.0034569724854305),
#   ('как я могу забыть свою жену', 1.0034569724854305),
#   ('какой штатив я должен получить для своего canon 6d', 1.0034569724854305),
#   ('где я могу опубликовать свою статью', 1.0034569724854305),
#   ('как я могу улучшить свою концентрацию', 1.0034569724854305),
#   ('как я могу поддерживать свое спокойствие', 1.0034569724854305),
#   ('вы когда-нибудь сожалели о своем разводе', 5.80363434030812)],
#  'выиграет в 2019 году': [('сколько человек может измениться от рождения до смерти в течение примерно 70 лет',
#    0.38930282365705987),
#   ('как тринадцать лет, что самое лучшее, что я могу сделать для своего здоровья',
#    0.4780702621555538),
#   ('Я 19-летний парень, как я могу стать миллиардером в ближайшие 10 лет',
#    0.6004869663023032),
#   ('может нарэндра modi стать премьер-министром Индии в 2019 году',
#    0.6004869663023032),
#   ('как мне пережить кого-то, кого я любил сейчас, когда мы расстались в прошлом году, и я все еще скучаю по ней',
#    0.6004869663023032),
#   ('если каждое государство США объявит войну друг другу, которая выиграет',
#    0.6439397193055143),
#   ('какие самые интересные продукты и инновации выходят в 2016 году',
#    0.7755476270747867),
#   ('какие книги стоит читать в начале 20-х годов', 0.7755476270747867),
#   ('мне почти 40 лет, мне слишком поздно изучать фортепиано',
#    1.0373100845458922),
#   ('каково ваше творческое разрешение нового года на 2017 год',
#    1.1361636780215156)],
#  'выпивает 4 литра воды каждый день нездоровым': [('почему девочки-подростки и женщины вообще позволяют своим бойфрендам снимать обнаженные фотографии из них в этот день и в цифровой век',
#    0.21594386013375347),
#   ('сколько способов 12 яблок могут быть распределены среди 4 детей, так что каждый ребенок получает по меньшей мере 2 яблока',
#    0.2833286327499377),
#   ('если каждое государство США объявит войну друг другу, которая выиграет',
#    0.5494892807687253),
#   ('насколько важно быть первым, кто пожелает кому-то счастливого дня рождения',
#    0.7405944515485053),
#   ('я могу принять инъекцию бешенства после 1 дня укуса собаки',
#    0.7405944515485053),
#   ('сколько раз в день перекрывают руки часы', 1.2793384973542465),
#   ('что это такое, как на сегодняшний день пума или сахарный папа',
#    1.2793384973542465),
#   ('сколько литров воды я должен выпить, если я буду работать 5000 мс ежедневно',
#    1.511666876420801),
#   ('какая рыба выживет в соленой воде', 2.1880231619719566),
#   ('здорово есть целый авокадо каждый день', 2.7434706270337825)],
#  'где я могу купить лучшие качественные кексы на золотом побережье': [('какие лучшие культовые плакаты',
#    1.2496845090955195),
#   ('это Volkswagen хороший надежный автомобиль', 1.2496845090955195),
#   ('какие хорошие рецепты пиццы', 1.2496845090955195),
#   ('как я могу найти хорошего эскорта', 1.4605704323106414),
#   ('может быть взломан', 1.4626337927360094),
#   ('как я могу писать в narendra modi', 1.4626337927360094),
#   ('как я могу присоединиться к', 1.4626337927360094),
#   ('что похоже на 4shared, но лучше', 1.995995633252668),
#   ('на котором можно купить мото или один плюс 3 т', 2.400088683911345),
#   ('где я могу найти вкусные кексы на золотом побережье', 4.1785996718572695)],
#  'где я могу найти базу данных европейского семейного офиса': [('может быть взломан',
#    1.4626337927360094),
#   ('как я могу писать в narendra modi', 1.4626337927360094),
#   ('как я могу присоединиться к', 1.4626337927360094),
#   ('как бы вы нашли нуль функции для математики y = frac 4x ^ 2 - 36x x - 9 math',
#    1.7295462981889127),
#   ('какова основная платформа данных', 1.8594789223432986),
#   ('что такое офисная культура и вокализм в офисе patanjali haridwar',
#    2.1880231619719566),
#   ('где я могу найти диаграмму преобразования для cc to horsepower',
#    2.3472128382687054),
#   ('как я могу найти хорошего эскорта', 2.3472128382687054),
#   ('как я могу найти работу в Японии', 2.3472128382687054),
#   ('где я могу найти американскую базу данных семейного офиса',
#    4.6329101299907025)],
#  'где я могу смотреть гонульцен с английскими субтитрами': [('может увеличить рост после 25',
#    0.9157488938406094),
#   ('как я могу просмотреть удаленные instagram dms', 0.9157488938406094),
#   ('могу я заработать деньги на quora', 0.9157488938406094),
#   ('Каким образом можно смотреть комедийные ночи с капилом на концертах',
#    1.169474507391589),
#   ('может быть взломан', 1.4626337927360094),
#   ('как я могу писать в narendra modi', 1.4626337927360094),
#   ('как я могу присоединиться к', 1.4626337927360094),
#   ('почему не должен я смотреть порно', 2.1880231619719566),
#   ('как я готовлюсь к net jrf в английской литературе', 3.558357810878418),
#   ('где можно посмотреть sarrainodu с субтитрами', 5.683407772417998)],
#  'гравитация - только теория': [('в чем разница между астероидами и кометами',
#    0.0),
#   ('почему нерафинированное молоко хорошо для вас', 0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('согласно m-теории существует 11 измерений, почему только 5 измерений в отношении гравитации рассматриваются в межзвездных',
#    1.0212675722224678),
#   ('каковы ваши теории о бермудском треугольнике', 1.5641949737016652)],
#  'действительно ли будет какая-то война между Индией и Пакистаном над нападением на ури, каковы будут ее последствия': [('каковы ваши взгляды на запрет на 500 и 1000 рупий в Индии?',
#    1.284402257356535),
#   ('каково это быть в отношениях с кем-то, кого вы обманывали',
#    1.3664144185382459),
#   ('каковы требования к выбору в', 1.3664144185382459),
#   ('как я могу получить доступ к google com из Индии', 1.4814092879175873),
#   ('действительно ли произошло махабхарата или только аллегория в соответствии с m k gandhi',
#    1.5641949737016652),
#   ('как страны должны предотвращать войну', 1.78956096348343),
#   ('каково это жить в k ln germany', 2.1824366012104877),
#   ('каково это быть пожарным', 2.1824366012104877),
#   ('кто победит, если начнется война между Индией и Пакистаном',
#    3.80251470043713),
#   ('будет ли ядерная война между Индией и Пакистаном', 5.3190237650528)],
#  'действительно ли махабхарата действительно произошло': [('что это за картина?',
#    0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('что происходит, когда вы заполняете бензиновый автомобиль дизельным топливом, каково решение, если такой инцидент произошел',
#    0.4139013146168828),
#   ('что произойдет, если правительство Индии украдет кохинор кох-и-ноор-алмаз назад',
#    0.49889503806039087),
#   ('в древних римских рабах заклеймили то, что произошло с маркой, если они впоследствии были освобождены',
#    0.6126513016092038),
#   ('что произойдет, если глазная медицина попадет в глаза', 1.329322118058481),
#   ('действительно ли крикетцы пьют чай во время перерыва на чай',
#    1.810989227728594),
#   ('действительно ли произошло махабхарата или только аллегория в соответствии с m k gandhi',
#    6.173510472471767)],
#  'делает ли общество слишком большое значение для спорта': [('что вы делаете, хотя зная лучше',
#    1.3242077676092154),
#   ('приседания делают мои ноги более толстыми', 1.3242077676092154),
#   ('могу ли я делать 30 000 ежемесячных торгов', 1.3242077676092154),
#   ('что делает понимание смерти философским', 1.3242077676092154),
#   ('что я должен делать, чтобы быть хорошим оратором', 1.3242077676092154),
#   ('имеет ли значение, является ли человечество злом или нет',
#    1.464132129679536),
#   ('мне почти 40 лет, мне слишком поздно изучать фортепиано',
#    1.715798407009956),
#   ('делать приседания для мужчин', 1.9632628930274056),
#   ('что теперь будет делать клинтон', 3.135722762736254),
#   ('как спорт вносит свой вклад в общество', 3.431596814019912)],
#  'делать мексиканские девушки, как черные парни': [('что вы делаете, хотя зная лучше',
#    1.3242077676092154),
#   ('приседания делают мои ноги более толстыми', 1.3242077676092154),
#   ('могу ли я делать 30 000 ежемесячных торгов', 1.3242077676092154),
#   ('что делает понимание смерти философским', 1.3242077676092154),
#   ('что я должен делать, чтобы быть хорошим оратором', 1.3242077676092154),
#   ('черная дыра имеет конечную массу', 1.3892421594854605),
#   ('как ребята чувствуют себя после отказа от девушки', 1.78956096348343),
#   ('делать приседания для мужчин', 1.9632628930274056),
#   ('девушки любят черных парней без бороды', 2.668580656839707),
#   ('что теперь будет делать клинтон', 3.135722762736254)],
#  'делать порно звезды смотреть порно': [('что вы делаете, хотя зная лучше',
#    1.3242077676092154),
#   ('приседания делают мои ноги более толстыми', 1.3242077676092154),
#   ('могу ли я делать 30 000 ежемесячных торгов', 1.3242077676092154),
#   ('что делает понимание смерти философским', 1.3242077676092154),
#   ('что я должен делать, чтобы быть хорошим оратором', 1.3242077676092154),
#   ('является нейтронной звездой, состоящей только из нейтронов',
#    1.715798407009956),
#   ('делать приседания для мужчин', 1.9632628930274056),
#   ('что теперь будет делать клинтон', 3.135722762736254),
#   ('почему не должен я смотреть порно', 6.564069485915869),
#   ('как ты впервые в порно', 10.362473627196492)],
#  'дома, устойчивые к землетрясениям': [('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('каковы некоторые советы о том, чтобы сделать это через процесс собеседования на дому в медицинской медицине',
#    0.5213830497636446),
#   ('каковы были основные последствия землетрясения в Камбодже и как эти эффекты сравниваются с землетрясением в Вальпараисо в 1822 году',
#    0.9450679613371028),
#   ('каковы некоторые неписанные правила для вашего дома', 1.0386705733154709),
#   ('ты бы жил в крошечном доме', 2.8811197569657176),
#   ('как работают здания, устойчивые к землетрясениям', 4.588111845883302),
#   ('что такое дом-дорси', 4.601723404528499)],
# ...
#    4.282759251245606)],
#  'это правда, что для того, чтобы быть частью элиты или просто богатой и успешной, вам нужно присоединиться к секретной организации, иначе шансов не было': [('что это за картина?',
#    0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('который является самым богатым игроком всех времен и как я могу достичь его уровня в качестве игрока',
#    0.4501926659588229),
#   ('как вы можете персонализировать приглашение linkedin, я думаю, что я просто послал коллеге приглашение на linkedin, но не получил возможность персонализировать его!',
#    0.4501926659588229),
#   ('как я могу задать вопрос, не указывая, как нужно улучшить',
#    1.2828212151025309),
#   ('насколько успешным был делийский нечетный - даже план', 1.715798407009956),
#   ('у rahul gandhi есть шансы стать следующим pm of india после modi',
#    3.558357810878418),
#   ('как я могу присоединиться к', 5.683407772417998)],
#  'я должен изучить angularjs 1 5 вместо angularjs 2, если я не знаю машинописи': [('какой штатив я должен получить для своего canon 6d',
#    1.2254850725603617),
#   ('я должен переключиться с spotify на яблочную музыку', 1.2254850725603617),
#   ('сколько денег я должен поднять', 1.2254850725603617),
#   ('как страны должны предотвращать войну', 1.2254850725603617),
#   ('что я должен делать, чтобы быть хорошим оратором', 1.2254850725603617),
#   ('почему не должен я смотреть порно', 1.2254850725603617),
#   ('какой вопрос я должен задать на quora', 1.8168971877128959),
#   ('что я должен просить о моей подавленности', 1.8168971877128959),
#   ('что вы делаете, хотя зная лучше', 1.9432961195040126),
#   ('когда вы используете вместо', 5.683407772417998)],
#  'я должен использовать пузырьки пара для засохшего носа': [('как страны должны предотвращать войну',
#    1.2254850725603617),
#   ('что я должен делать, чтобы быть хорошим оратором', 1.2254850725603617),
#   ('почему не должен я смотреть порно', 1.2254850725603617),
#   ('как я могу использовать твиттер для бизнеса', 1.7295462981889127),
#   ('какой вопрос я должен задать на quora', 1.8168971877128959),
#   ('что я должен просить о моей подавленности', 1.8168971877128959),
#   ('хуже ли использовать кого-то или быть материалистичным',
#    2.5642154894905134),
#   ('как вы применяете пузырьки пара, чтобы лечить душный нос',
#    3.7351169375966506),
#   ('когда вы используете вместо', 4.0955640263527595),
#   ('то, что использует объектив word для ocr', 4.0955640263527595)],
#  'я должен купить tiago': [('что я должен делать, чтобы быть великим геологом?',
#    1.2254850725603617),
#   ('какой штатив я должен получить для своего canon 6d', 1.2254850725603617),
#   ('я должен переключиться с spotify на яблочную музыку', 1.2254850725603617),
#   ('сколько денег я должен поднять', 1.2254850725603617),
#   ('как страны должны предотвращать войну', 1.2254850725603617),
#   ('что я должен делать, чтобы быть хорошим оратором', 1.2254850725603617),
#   ('почему не должен я смотреть порно', 1.2254850725603617),
#   ('какой вопрос я должен задать на quora', 1.8168971877128959),
#   ('что я должен просить о моей подавленности', 1.8168971877128959),
#   ('на котором можно купить мото или один плюс 3 т', 2.400088683911345)],
#  'я должен повторить 2-й курс в колледже или найти новый колледж 5-го курса': [('где я могу найти диаграмму преобразования для cc to horsepower',
#    1.7295462981889127),
#   ('как я могу найти хорошего эскорта', 1.7295462981889127),
#   ('как я могу найти работу в Японии', 1.7295462981889127),
#   ('как бы вы нашли нуль функции для математики y = frac 4x ^ 2 - 36x x - 9 math',
#    1.7295462981889127),
#   ('какой вопрос я должен задать на quora', 1.8168971877128959),
#   ('что я должен просить о моей подавленности', 1.8168971877128959),
#   ('курсы Гарвардского колледжа: что такое общий совет по шопингу для уроков тамила',
#    2.5610677974793314),
#   ('какие курсы необходимо проводить вместе с курсом', 5.058508613226329),
#   ('какой курс лучше в никмаре', 5.762239513931435),
#   ('предпочтительные курсы pg для ученика eee в tamil nadu',
#    5.762239513931435)],
#  'я могу использовать jio sim в iphone 5s': [('как я могу просмотреть удаленные instagram dms',
#    0.9157488938406094),
#   ('могу я заработать деньги на quora', 0.9157488938406094),
#   ('какой тип ленты можно использовать для подъема 200 кг непрерывно',
#    0.9244236259649562),
#   ('может быть взломан', 1.4626337927360094),
#   ('как я могу писать в narendra modi', 1.4626337927360094),
#   ('как я могу присоединиться к', 1.4626337927360094),
#   ('как я могу использовать твиттер для бизнеса', 2.3472128382687054),
#   ('хуже ли использовать кого-то или быть материалистичным',
#    2.5642154894905134),
#   ('когда вы используете вместо', 4.0955640263527595),
#   ('то, что использует объектив word для ocr', 4.0955640263527595)],
#  'я неожиданно вышел из gmail, я не могу вспомнить свой пароль gmail и только понял, что адрес электронной почты восстановления больше не жив, что я могу сделать': [('как я могу улучшить свою концентрацию',
#    2.238790052645016),
#   ('как я могу поддерживать свое спокойствие', 2.238790052645016),
#   ('когда я могу ожидать знакомой почты подтверждения', 2.272368914456158),
#   ('что я могу сделать, чтобы сделать мир лучше', 2.8112224186818002),
#   ('что я должен делать, если я забыл свой пароль по электронной почте',
#    2.914627237525201),
#   ('может быть взломан', 2.9252675854720187),
#   ('как я могу писать в narendra modi', 2.9252675854720187),
#   ('как я могу присоединиться к', 2.9252675854720187),
#   ('Я не могу вспомнить мой пароль gmail или мой адрес электронной почты для восстановления, как я могу восстановить свой адрес электронной почты',
#    3.0613238022167057),
#   ('что я могу сделать, чтобы не ревновать кого-то', 4.027826759233546)],
#  'я получил 3 8 gpa, достаточно ли получить лучшие университеты, такие как гарвард': [('как я могу получить бесплатное сражение камней кланов',
#    1.5510952541495735),
#   ('достаточно 3 8 гпа, чтобы попасть в высшую школу', 1.715798407009956),
#   ('что похоже на 4shared, но лучше', 1.995995633252668),
#   ('могу ли я получить работу в консалтинговой фирме после mtech в cse от iit',
#    2.0746201690917845),
#   ('когда мы получим письмо с призывом после того, как мы получим письмо о намерениях в призыве asahi india glass recruitment',
#    2.2723273560430313),
#   ('как я могу получить skype для работы на телефоне Android 4 1 1',
#    2.9020148118266325),
#   ('как я могу получить доступ к google com из Индии', 2.9020148118266325),
#   ('какой штатив я должен получить для своего canon 6d', 2.9020148118266325),
#   ('как получить трафик для сайта', 4.302510628948743),
#   ('как получить уведомления о значке facebook на htc 10', 4.302510628948743)],
#  'я получил предложение на работу chelmsford - essex london с оплатой в 3764 п.п. - после получения налоговых вычетов': [('как я могу получить бесплатное сражение камней кланов',
#    0.7755476270747867),
#   ('когда мы получим письмо с призывом после того, как мы получим письмо о намерениях в призыве asahi india glass recruitment',
#    1.1361636780215156),
#   ('как я могу получить доступ к google com из Индии', 1.4510074059133162),
#   ('какой штатив я должен получить для своего canon 6d', 1.4510074059133162),
#   ('как я могу найти работу в Японии', 1.8594789223432986),
#   ('как получить трафик для сайта', 2.1512553144743713),
#   ('как получить уведомления о значке facebook на htc 10', 2.1512553144743713),
#   ('могу ли я получить работу в консалтинговой фирме после mtech в cse от iit',
#    2.3666322026043733),
#   ('есть хорошая оплата для сайтов отзывов там', 2.400088683911345),
#   ('как я могу получить skype для работы на телефоне Android 4 1 1',
#    3.310486328256615)],
#  'я спорил с моим gf, что она подружилась с человеком, который ударил ее, она сказала, что я контрольный урод, и она хочет ее свободы, что я должен делать': [('что я должен делать, когда мой лучший друг игнорирует меня',
#    1.8227488604288786),
#   ('делать животных, кроме людей, целует', 1.877923612851983),
#   ('делать приседания для мужчин', 1.9632628930274056),
#   ('который является sandeep maheshwari', 2.1824366012104877),
#   ('в изюминке на солнце, почему walter и beneatha спорят', 2.400088683911345),
#   ('что я должен делать, чтобы быть великим геологом?', 2.549692840169577),
#   ('что я должен делать, чтобы быть хорошим оратором', 2.549692840169577),
#   ('как люди умирают', 3.084708270236677),
#   ('что теперь будет делать клинтон', 3.135722762736254),
#   ('как подружиться', 9.860176855040681)],
#  'я существую': [('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0),
#   ('согласно m-теории существует 11 измерений, почему только 5 измерений в отношении гравитации рассматриваются в межзвездных',
#    0.3983382798657495),
#   ('какие существуют разумные технологии, которые большинство людей не знают о',
#    0.7405944515485053),
#   ('атеизм - отсутствие веры в богов или утверждение, что бог не существует',
#    0.7405944515485053),
#   ('daniel ek: существуют ли какие-либо планы на будущее в области выделения в Индии?',
#    0.7405944515485053),
#   ('существует ли гравитационная сила во всех планетах', 1.78956096348343),
#   ('мы существуем', 7.351973162953093)],
#  'является нейтронной звездой, состоящей из': [('имеет ли значение, является ли человечество злом или нет',
#    0.7974002161968086),
#   ('который является отцом лорда кришны', 0.7974002161968086),
#   ('какими срочными вкладами являются временные депозиты rd и fd',
#    0.7974002161968086),
#   ('который является лучшим языком программирования', 0.7974002161968086),
#   ('который является лучшим общежитием не девочек в srm', 0.7974002161968086),
#   ('который является лучшим наушниками под RS 1000', 1.1154173052168566),
#   ('что является биологической причиной плача', 1.1154173052168566),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('который является sandeep maheshwari', 2.641307141879423),
#   ('является нейтронной звездой, состоящей только из нейтронов',
#    5.944795437226676)],
#  'является одним плюс 3t 4g вольт включен телефон': [('который является лучшим наушниками под RS 1000',
#    1.1154173052168566),
#   ('что является биологической причиной плача', 1.1154173052168566),
#   ('что такое номер телефона службы поддержки клиентов quickbooks usa',
#    1.2793384973542465),
#   ('почему телефоны не имеют встроенной антенны fm', 1.2793384973542465),
#   ('которые являются лучшими мобильными телефонами для покупки до 15000',
#    1.5526791895153993),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('как я могу получить skype для работы на телефоне Android 4 1 1',
#    1.78956096348343),
#   ('на котором можно купить мото или один плюс 3 т', 2.048053513651783),
#   ('как я переношу свои контакты с одного телефона Android на другой Android-телефон',
#    2.3291636968803835),
#   ('который является sandeep maheshwari', 2.641307141879423)],
#  'является правилом моргана, когда он говорит, что единственный способ остановить расизм - прекратить говорить об этом': [('какой лучший способ прыгать с веревкой',
#    1.5494131611199722),
#   ('что было бы лучшим способом удержаться в тюрьме', 1.5494131611199722),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('Я тройная луна-козерог и восхождение в козероге, что это говорит обо мне',
#    1.987742391860789),
#   ('каковы ваши взгляды на эту цитату моргана о расизме', 2.5656424302050618),
#   ('который является sandeep maheshwari', 2.641307141879423),
#   ('как я могу научиться свободно говорить по-английски', 2.658644236116962),
#   ('как я могу говорить с большей ясностью и уверенностью', 2.658644236116962),
#   ('как я могу свободно говорить по-китайски', 3.718957844686597),
#   ('что правильно: говорить или говорить с', 9.156258650743686)],
#  'является профессиональным пусковым установкой, пригодным для подготовки rbi b': [('является нейтронной звездой, состоящей только из нейтронов',
#    0.7974002161968086),
#   ('какими срочными вкладами являются временные депозиты rd и fd',
#    0.7974002161968086),
#   ('который является лучшим языком программирования', 0.7974002161968086),
#   ('который является лучшим общежитием не девочек в srm', 0.7974002161968086),
#   ('Каковы наилучшие способы подготовки к интервью с программным обеспечением?',
#    0.905494613864297),
#   ('который является лучшим наушниками под RS 1000', 1.1154173052168566),
#   ('что является биологической причиной плача', 1.1154173052168566),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('какую книгу я начинаю с подготовки ворот', 2.1880231619719566),
#   ('который является sandeep maheshwari', 2.641307141879423)],
#  'является розоватым нормальным разрядом на ранней беременности, что вызывает его': [('который является лучшим общежитием не девочек в srm',
#    0.7974002161968086),
#   ('что вызывает темное кольцо вокруг радужки, как его следует лечить',
#    0.8042164269268487),
#   ('который является лучшим наушниками под RS 1000', 1.1154173052168566),
#   ('что является биологической причиной плача', 1.1154173052168566),
#   ('что вызывает кошмары, которые кажутся реальными', 1.3892421594854605),
#   ('это нормально, если 14-летняя девочка будет плевать кровью',
#    1.5641949737016652),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('то, что вызывает любовь в любви, означает', 1.9432961195040126),
#   ('который является sandeep maheshwari', 2.641307141879423),
#   ('как витамин c вызывает выкидыш', 2.8811197569657176)],
#  'является самой могущественной страной мира': [('который является лучшим наушниками под RS 1000',
#    1.1154173052168566),
#   ('что является биологической причиной плача', 1.1154173052168566),
#   ('что я могу сделать, чтобы сделать мир лучше', 1.3892421594854605),
#   ('самая дешевая зубная паста', 1.5140846010313136),
#   ('что самое лучшее, что вы когда-либо узнали о quora', 1.5140846010313136),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('что является самым сильным шнуром кевлара', 1.8798035306835799),
#   ('как страны должны предотвращать войну', 2.048053513651783),
#   ('который является sandeep maheshwari', 2.641307141879423),
#   ('почему США - самая могущественная страна мира', 4.225415745591912)],
#  'является хорошим ребенком и не является повстанцем, которого он стоит в долгосрочной перспективе': [('что является биологической причиной плача',
#    2.230834610433713),
#   ('который является отцом лорда кришны', 2.253669440865982),
#   ('который является лучшим игровым ноутбуком под rs 60000',
#    2.8562526559142154),
#   ('которые являются одними из лучших художественных романов',
#    2.8562526559142154),
#   ('который является лучшим языком программирования', 2.8562526559142154),
#   ('который является лучшим общежитием не девочек в srm', 2.8562526559142154),
#   ('который является лучшим наушниками под RS 1000', 3.995375942677195),
#   ('скучает хорошо для ребенка', 4.601723404528499),
#   ('которые являются ронингами', 4.673837104219279),
#   ('который является sandeep maheshwari', 7.465050884969334)],
#  'являются государственными служащими, имеющими право на sukanya samriddhi yojana': [('что является биологической причиной плача',
#    1.1154173052168566),
#   ('черная дыра имеет конечную массу', 1.1351578915008596),
#   ('почему телефоны не имеют встроенной антенны fm', 1.1351578915008596),
#   ('кто-нибудь когда-либо имел почти смертельный опыт', 1.1351578915008596),
#   ('которые являются ронингами', 1.6537113428405166),
#   ('имеет ли значение, является ли человечество злом или нет',
#    1.9325581076976681),
#   ('может ли правительственный служащий применять iec', 2.400088683911345),
#   ('который является sandeep maheshwari', 2.641307141879423),
#   ('как я готовлюсь к государственной службе', 3.558357810878418),
#   ('если я в тюрьме, какие права у меня есть', 5.181236813598246)]}

# %%
scores = 0
for key in bm:
    for i in all:
        if key == i[1] and i[3] == '1':
            for z in bm[key]:
                if z[0] == i[2]:
                    scores += 1

# %%
print('Настолько верно для 500 запросов: ',scores*100/len(bm), '%')
# Out:
# Настолько верно для 500 запросов:  35.010060362173036 %

# %% [markdown]
# ### __Задача 1__:
# Напишите два поисковика на *BM25*. Один через подсчет метрики по формуле для каждой пары слово-документ, второй через умножение матрицы на вектор.
#
# Сравните время работы поиска на 100к запросах. В качестве корпуса возьмем
# [Quora question pairs](https://www.kaggle.com/loopdigga/quora-question-pairs-russian).

# %% [markdown]
# ### __Задача 2__:

# %% [markdown]
# Выведите 10 первых результатов и их близость по метрике BM25 по запросу **рождественские каникулы** на нашем корпусе  Quora question pairs.

# %%
bmCh = {}
christmas = ['рождественский', 'каникулы']
temp = {}
for t in range(len(all)):
    try:
        temp[all[t][2]] = bm25(normal[t][1], christmas)
    except ZeroDivisionError:
        pass
bmCh['рождественские каникулы'] = sorted(temp.items(), key=itemgetter(1))[-10:]

# %%
bmCh
# Out:
# {'рождественские каникулы': [('у rahul gandhi есть шансы стать следующим pm of india после modi',
#    0.0),
#   ('хорошо делать спортзал утром и плавать в полдень', 0.0),
#   ('в чем разница между астероидами и кометами', 0.0),
#   ('почему нерафинированное молоко хорошо для вас', 0.0),
#   ('какие уловки для эффективного изучения', 0.0),
#   ('которая является лучшей страной для высшего образования после США и Великобритании',
#    0.0),
#   ('что это за картина?', 0.0),
#   ('которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#    0.0),
#   ('если пространство расширяется, где новое пространство исходит из', 0.0),
#   ('может лысый человек когда-либо вырастить свои волосы назад', 0.0)]}

# %% [markdown]
# ### __Задача 3__:
#
# Посчитайте точность поиска при
# 1. BM25, b=0.75
# 2. BM15, b=0
# 3. BM11, b=1
